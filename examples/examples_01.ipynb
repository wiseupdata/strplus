# %% [markdown]
# # Examples! ❤️
#
# ## Extend your string powers with Str+ 🚀
#
# Env setup 🔧
#
# [Optional]
#
# > Create a new virtualenv before start this notebook to be able to select it as the kernel, if you want!
# >
# > * Create a new virtualenv.
# >
# >   ```
# >   virtualenv 3.9.16 .envStrPlus
# >   pyenv activate .envStrPlus
# >   pip install --upgrade pip
# >   pip install ipykernel
# >   ```
# >
# > * Delete the virtualenv.
# >
# >   ```
# >   pyenv deactivate .envStrPlus
# >   pyenv virtualenv-delete -f .envStrPlus
# >   ```
# >
# >   should return empty
# >
# >   ```
# >   versions | grep .envStrPlus
# >   ```
# >
#
# ### Required! 💢

# %%
pip install strplus
# Out:
# Collecting strplus
#   Downloading strplus-0.0.11-py3-none-any.whl (5.7 kB)
# Installing collected packages: strplus
# Successfully installed strplus-0.0.11
# Note: you may need to restart the kernel to use updated packages.

# %%
from strplus import Str
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from strplus import Str
#       2 from strplus.functions import *
#
# ModuleNotFoundError: No module named 'strplus'

# %% [markdown]
# ## Simples use 😍 no parentheses (), just call!

# %%
my_string = Str("My_string")

my_string.pascal
my_string.pascal
# Out:
# 'MyString'

# %% [markdown]
# ## Normally, built-in functions used with parentheses () ! 🔥

# %%
my_string.to_camel()
# Out:
# 'myString'

# %%
my_string.upper()
# Out:
# 'MY_STRING'

# %%
Str("MyStringWorks").to_snake()
# Out:
# 'my_string_works'

# %% [markdown]
# ### Snake examples

# %%
Str("myPath/2021/01/01").to_snake()e()
# Out:
# 'my_path_2021_01_01'

# %% [markdown]
# ### Pascal examples

# %%
Str("myPath/2021/01/01").pascal
# Out:
# 'MyPath20210101'

# %%
Str("reference dataset").pascal
# Out:
# 'ReferenceDataset'

# %% [markdown]
# ### Camel

# %%
Str("reference dataset").to_camel()
# Out:
# 'referenceDataset'

# %% [markdown]
# ### Complex examples

# %%
# Complex return, recursive Str
Str("MyStringWorks").to_snake().split("_")[0].pascal
# Out:
# 'My'

# %% [markdown]
# ```ad-note
#
# "_".join returns a str class not a not or Str with the good features!
# In the Str we only have recessivity we are not overwriting the str from the global to Str, so it's normal and expected that behavior
# ```

# %%
try:
    "_".join(Str("MyStringWorks").to_snake().split("_")[0:1]).pascal
except Exception as e:
    print(e)
# Out:
# 'str' object has no attribute 'pascal'

# %% [markdown]
# ## Just use a specif function if you prefer!😏

# %%
from strplus.functions import *

# %%
###Local Test
import os 
import sys 
sys.path.insert(0, os.path.abspath("../.."))
sys.path.insert(0, os.path.abspath(".."))
